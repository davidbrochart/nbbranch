# %%
# %load_ext nbbranch

# %%
a = 1

# %%
# %%IF a == 0:
# print('foo')

# %%
# %%ELIF a == 1:
# print('baz1')
# Out:
# baz1

# %%
# %%IF True:
# print('True')
# Out:
# True

# %%
# %ENDIF

# %%
# %%IF
# print('baz2')
# Out:
# baz2

# %%
# %%ELIF a == 2:
# print('bar')

# %%
# %%ELSE
# print('ERROR')

# %%
# %ENDIF
